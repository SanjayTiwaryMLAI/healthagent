# %%
import boto3
import json

# Create a DynamoDB client
dynamodb = boto3.client('dynamodb', region_name='us-east-1')

# Define the table name
table_name = 'patients'


patient_records = [
  {
    "id": "PAT-0001",
    "dateOfBirth": "1990-01-01",
    "name": "John Doe",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 32,
    "gender": "Male",
    "diagnosis": "COLON, CECAL POLYP, SNARE: TUBULAR ADENOMA. COLON, SIGMOID POLYP AT 30 CM, SNARE: TUBULOVILLOUS ADENOMA."
  },
  {
    "id": "PAT-0002",
    "dateOfBirth": "1985-05-15",
    "name": "Jane Smith",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 37,
    "gender": "Female",
    "diagnosis": "Kidney function test showing high creatinine levels, indicating potential chronic kidney disease."
  },
  {
    "id": "PAT-0003",
    "dateOfBirth": "1992-09-22",
    "name": "Michael Johnson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 30,
    "gender": "Male",
    "diagnosis": "Elevated liver enzyme levels (ALT 100.50 U/L), suggesting liver disease such as non-alcoholic fatty liver disease (NAFLD)."
  },
  {
    "id": "PAT-0004",
    "dateOfBirth": "1988-03-10",
    "name": "Emily Davis",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 34,
    "gender": "Female",
    "diagnosis": "Low hemoglobin levels (12.5 g/dL), indicating potential anemia or blood loss."
  },
  {
    "id": "PAT-0005",
    "dateOfBirth": "1995-07-18",
    "name": "David Wilson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 27,
    "gender": "Male",
    "diagnosis": "Complete blood count showing low hemoglobin (12.5 g/dL) and high packed cell volume (57.5%), suggesting potential anemia or hematological disorder."
  },
  {
    "id": "PAT-0006",
    "dateOfBirth": "1982-11-03",
    "name": "Sophia Thompson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 40,
    "gender": "Female",
    "diagnosis": "Ultrasound anomaly scan showing a single live fetus in variable presentation, corresponding to 20-21 weeks of gestation."
  },
  {
    "id": "PAT-0007",
    "dateOfBirth": "1978-06-28",
    "name": "William Anderson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 44,
    "gender": "Male",
    "diagnosis": "CT KUB study within normal limits, showing no evidence of kidney stones or other abnormalities."
  },
  {
    "id": "PAT-0008",
    "dateOfBirth": "1991-02-14",
    "name": "Olivia Martinez",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 31,
    "gender": "Female",
    "diagnosis": "CT abdomen study showing no significant abnormalities in the abdominal organs and structures."
  },
  {
    "id": "PAT-0009",
    "dateOfBirth": "1986-09-05",
    "name": "James Robinson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 36,
    "gender": "Male",
    "diagnosis": "MRI brain scan showing a well-defined extra-axial hematoma, potentially indicating a subdural or epidural hemorrhage."
  },
  {
    "id": "PAT-0010",
    "dateOfBirth": "1980-12-20",
    "name": "Emma Clark",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 42,
    "gender": "Female",
    "diagnosis": "Histopathology report describing a gastrointestinal biopsy specimen with findings consistent with a tubular adenoma and tubulovillous adenoma."
  },
  {
    "id": "PAT-0011",
    "dateOfBirth": "1993-04-08",
    "name": "Daniel Rodriguez",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 29,
    "gender": "Male",
    "diagnosis": "Kidney function test results within normal range, indicating healthy kidney function."
  },
  {
    "id": "PAT-0012",
    "dateOfBirth": "1989-07-25",
    "name": "Ava Lewis",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 33,
    "gender": "Female",
    "diagnosis": "Liver panel showing elevated AST and ALT levels, suggesting potential liver disease or injury."
  },
  {
    "id": "PAT-0013",
    "dateOfBirth": "1984-11-12",
    "name": "Matthew Walker",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 38,
    "gender": "Male",
    "diagnosis": "Hemoglobin test within normal range, indicating no evidence of anemia or blood disorders."
  },
  {
    "id": "PAT-0014",
    "dateOfBirth": "1996-03-28",
    "name": "Isabella Hall",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 26,
    "gender": "Female",
    "diagnosis": "Complete blood count showing elevated white blood cell count (9000 cumm), indicating potential infection or inflammatory condition."
  },
  {
    "id": "PAT-0015",
    "dateOfBirth": "1975-08-10",
    "name": "Jacob Young",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 47,
    "gender": "Male",
    "diagnosis": "CT scan of the abdomen and pelvis showing no significant abnormalities."
  },
  {
    "id": "PAT-0016",
    "dateOfBirth": "1998-12-05",
    "name": "Mia King",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 24,
    "gender": "Female",
    "diagnosis": "MRI brain scan showing no evidence of structural abnormalities or lesions."
  },
  {
    "id": "PAT-0017",
    "dateOfBirth": "1983-06-19",
    "name": "Benjamin Brown",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 39,
    "gender": "Male",
    "diagnosis": "Liver panel within normal limits, indicating healthy liver function."
  },
  {
    "id": "PAT-0018",
    "dateOfBirth": "1977-09-30",
    "name": "Sophia Garcia",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 45,
    "gender": "Female",
    "diagnosis": "Kidney function test results showing elevated creatinine levels, suggesting potential kidney disease."
  },
  {
    "id": "PAT-0019",
    "dateOfBirth": "1990-07-08",
    "name": "William Miller",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 32,
    "gender": "Male",
    "diagnosis": "Complete blood count within normal ranges, indicating no hematological abnormalities."
  },
  {
    "id": "PAT-0020",
    "dateOfBirth": "1987-02-22",
    "name": "Olivia Davis",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 35,
    "gender": "Female",
    "diagnosis": "Histopathology report describing a sessile serrated adenoma with low-grade dysplasia in the colon."
  },
  {
    "id": "PAT-0021",
    "dateOfBirth": "1981-10-15",
    "name": "James Wilson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 41,
    "gender": "Male",
    "diagnosis": "Hemoglobin test showing elevated levels, suggesting potential polycythemia vera or bone marrow disorder."
  },
  {
    "id": "PAT-0022",
    "dateOfBirth": "1994-05-03",
    "name": "Emma Anderson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 28,
    "gender": "Female",
    "diagnosis": "Ultrasound anomaly scan showing no significant fetal abnormalities."
  },
  {
    "id": "PAT-0023",
    "dateOfBirth": "1979-12-28",
    "name": "Daniel Thomas",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 43,
    "gender": "Male",
    "diagnosis": "CT scan of the brain showing no evidence of acute intracranial abnormalities or lesions."
  },
  {
    "id": "PAT-0024",
    "dateOfBirth": "1992-08-17",
    "name": "Ava Jackson",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 30,
    "gender": "Female",
    "diagnosis": "Kidney function test results within normal ranges, indicating healthy kidney function."
  },
  {
    "id": "PAT-0025",
    "dateOfBirth": "1985-11-05",
    "name": "Matthew White",
    "address": "125, Shivam Bungalow, S G Road, Mumbai",
    "age": 37,
    "gender": "Male",
    "diagnosis": "Liver panel showing elevated alkaline phosphatase (ALP) levels, suggesting potential biliary or hepatic disease."
  }
]

# %%
# Iterate over the patient records and add them to the DynamoDB table
for record in patient_records:
    try:
        response = dynamodb.put_item(
            TableName=table_name,
            Item={
                'id': {'S': record['id']},
                'dateOfBirth': {'S': record['dateOfBirth']},
                'name': {'S': record['name']},
                'address': {'S': record['address']},
                'age': {'N': str(record['age'])},
                'gender': {'S': record['gender']},
                'diagnosis': {'S': record['diagnosis']}
            }
        )
        print(f"Successfully added record: {record['id']}")
    except Exception as e:
        print(f"Error adding record {record['id']}: {str(e)}")

print("Data ingestion completed.")
# Out:
# Successfully added record: PAT-0001
# Successfully added record: PAT-0002
# Successfully added record: PAT-0003
# Successfully added record: PAT-0004
# Successfully added record: PAT-0005
# Successfully added record: PAT-0006
# Successfully added record: PAT-0007
# Successfully added record: PAT-0008
# Successfully added record: PAT-0009
# Successfully added record: PAT-0010
# Successfully added record: PAT-0011
# Successfully added record: PAT-0012
# Successfully added record: PAT-0013
# Successfully added record: PAT-0014
# Successfully added record: PAT-0015
# Successfully added record: PAT-0016
# Successfully added record: PAT-0017
# Successfully added record: PAT-0018
# Successfully added record: PAT-0019
# Successfully added record: PAT-0020
# Successfully added record: PAT-0021
# Successfully added record: PAT-0022
# Successfully added record: PAT-0023
# Successfully added record: PAT-0024
# Successfully added record: PAT-0025
# Data ingestion completed.
